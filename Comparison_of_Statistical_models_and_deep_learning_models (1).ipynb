# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df=pd.read_csv("/content/Five_models_Deep_learning_mini.csv").fillna(0)
df
# Out:
#      Model       MAE       MSE      RMSE        R2
# 0     LSTM  0.858193  1.309307  1.144249  0.975038
# 1  BI-LSTM  0.864876  1.319739  1.148799  0.974839
# 2      GRU  0.846310  1.319632  1.148752  0.974841
# 3      CNN  0.882476  1.351338  1.162471  0.974237
# 4      RNN  0.870142  1.332472  1.154328  0.974597

# %%
from matplotlib import pyplot
from matplotlib.pyplot import figure
figure(figsize=(10, 6), dpi=100)
plt.xlabel('Models', fontsize = 12, weight = 'bold')
plt.ylabel('Error Value', fontsize = 12, weight = 'bold')
N = len(df['MAE'])
my_colors=['g','r','c','m','y']
model=['LSTM','BI-LSTM','GRU','CNN','RNN']
for x,y,c,lb in zip(df['Model'],df['MAE'],my_colors,model,):
    plt.bar(x, y, color=c,label=lb,alpha = 0.55)
plt.legend(model)
plt.title("Mean Absolute Error",fontsize = 12, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Mean Absolute Error')

# %%
from matplotlib import pyplot
from matplotlib.pyplot import figure
figure(figsize=(10, 6), dpi=100)
plt.xlabel('Models', fontsize = 12, weight = 'bold')
plt.ylabel('Error Value', fontsize = 12, weight = 'bold')
N = len(df['RMSE'])
my_colors=['g','r','c','m','y']
model=['LSTM','BI-LSTM','GRU','CNN','RNN']
for x,y,c,lb in zip(df['Model'],df['RMSE'],my_colors,model,):
    plt.bar(x, y, color=c,label=lb,alpha = 0.55)
plt.legend(model)
plt.title("Root Mean Squared Error",fontsize = 12, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Root Mean Squared Error')

# %%
from matplotlib import pyplot
from matplotlib.pyplot import figure
figure(figsize=(10, 6), dpi=100)
plt.xlabel('Models', fontsize = 12, weight = 'bold')
plt.ylabel('Error Value', fontsize = 12, weight = 'bold')
N = len(df['R2'])
my_colors=['g','r','c','m','y']
model=['LSTM','BI-LSTM','GRU','CNN','RNN']
for x,y,c,lb in zip(df['Model'],df['R2'],my_colors,model,):
    plt.bar(x, y, color=c,label=lb,alpha = 0.55)
plt.legend(model)
plt.title("R2 Score Error",fontsize = 12, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'R2 Score Error')

# %%
df=pd.read_csv("/content/Statistical and DL models score mini.csv").fillna(0)
df
# Out:
#                          Model       MAE      RMSE        R2
# 0                         LSTM  0.858193  1.144249  0.975038
# 1                      BI-LSTM  0.864876  1.148799  0.974839
# 2                          GRU  0.846310  1.148752  0.974841
# 3                          CNN  0.882476  1.162471  0.974237
# 4                          RNN  0.870142  1.154328  0.974597
# 5             Naive Forecaster  2.523100  0.925400 -0.010300
# 6       Grand Means Forecaster  3.027400  1.003300 -0.149800
# 7  Polynomial Trend Forecaster  3.074700  0.999100 -0.140500
# 8    Seasonal Naive Forecaster  4.357400  1.211400 -0.691800
# 9                        ARIMA  4.394200  1.175900 -0.607300

# %%
from matplotlib import pyplot
from matplotlib.pyplot import figure
figure(figsize=(15, 6), dpi=100)
plt.xlabel('Models', fontsize = 12, weight = 'bold')
plt.ylabel('Error Value', fontsize = 12, weight = 'bold')
N = len(df['MAE'])
my_colors=['g','r','c','m','y', 'orange','pink','blue','brown','black']
model=['LSTM','BI-LSTM','GRU','CNN','RNN','huber_cds_dt','exp_smooth','arima','snaive','ets']
for x,y,c,lb in zip(df['Model'],df['MAE'],my_colors,model,):
    plt.bar(x, y, color=c,label=lb,alpha = 0.55)
plt.legend(model)
plt.title("Mean Absolute Error",fontsize = 12, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Mean Absolute Error')

# %%
from matplotlib import pyplot
from matplotlib.pyplot import figure
figure(figsize=(10, 6), dpi=100)
plt.xlabel('Models', fontsize = 12, weight = 'bold')
plt.ylabel('Error Value', fontsize = 12, weight = 'bold')
N = len(df['RMSE'])
my_colors=['g','r','c','m','y', 'orange','pink','blue','brown','black']
model=['LSTM','BI-LSTM','GRU','CNN','RNN','huber_cds_dt','exp_smooth','arima','snaive','ets']
for x,y,c,lb in zip(df['Model'],df['RMSE'],my_colors,model,):
    plt.bar(x, y, color=c,label=lb,alpha = 0.55)
plt.legend(model)
plt.title("Root Mean Squared Error",fontsize = 12, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Root Mean Squared Error')

# %%
from matplotlib import pyplot
from matplotlib.pyplot import figure
figure(figsize=(10, 6), dpi=100)
plt.xlabel('Models', fontsize = 12, weight = 'bold')
plt.ylabel('Error Value', fontsize = 12, weight = 'bold')
N = len(df['R2'])
my_colors=['g','r','c','m','y', 'orange','pink','blue','brown','black']
model=['LSTM','BI-LSTM','GRU','CNN','RNN','huber_cds_dt','exp_smooth','arima','snaive','ets']
for x,y,c,lb in zip(df['Model'],df['R2'],my_colors,model,):
    plt.bar(x, y, color=c,label=lb,alpha = 0.55)
plt.legend(model)
plt.title("R2 Score Error",fontsize = 12, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'R2 Score Error')
